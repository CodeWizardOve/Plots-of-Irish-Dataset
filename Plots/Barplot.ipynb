# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris = sns.load_dataset("iris")

# %%
g = sns.FacetGrid(iris.melt(id_vars="species"), col="variable", col_wrap=2, sharex=False, sharey=False)
g.map(sns.barplot, "species", "value", "species", order=iris["species"].unique(), palette="Set2", ci=None)
# Out:
# C:\Users\tanvi\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:723: UserWarning: Using the barplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# C:\Users\tanvi\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\tanvi\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\tanvi\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\tanvi\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
for ax, title in zip(g.axes.flatten(), ["Sepal Length", "Sepal Width", "Petal Length", "Petal Width"]):
    ax.set_title(f"Average {title}")
    ax.set_xlabel("Species")
    ax.set_ylabel(f"{title} (cm)")

# %%
g.fig.tight_layout()
plt.show()
